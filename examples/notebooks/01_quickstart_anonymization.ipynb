# %% [markdown]
# # Quickstart: anonymize CSV
# This notebook shows how to load a CSV and apply a built-in policy.

# %%
import pandas as pd
from ru_smb_pd_anonymizer.policies.model import Policy
from ru_smb_pd_anonymizer.pipeline.pandas_adapter import anonymize_csv

policy = Policy.from_yaml('examples/configs/policy_analytics.yaml')
anonymize_csv('examples/data/synthetic_crm.csv', 'examples/data/synthetic_crm_anon.csv', policy)
pd.read_csv('examples/data/synthetic_crm_anon.csv').head()
